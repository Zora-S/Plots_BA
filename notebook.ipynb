# %%
import numpy as np
import matplotlib.pyplot as plt
import test2

# %% [markdown]
# # Bearbewitung

# %%
x=3

# %% [markdown]
# ## einlesen

# %% [markdown]
# # Potten

# %%
x=np.arange(0,10,0.1)
y=[x_ for x_ in x]
test2.test

# %% [markdown]
# hier dies gemacht

# %%
plt.plot(x,y)
